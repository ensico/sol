-- %% [markdown]
-- # **Atividade** | Resoluções Aula Prática 6
--
-- #### Com o apoio do [Departamento de Informática](https://www.di.uminho.pt/ensino.html) da U. Minho
--
-- [<img src="./img/53689f31-ebda-470d-826c-350210b7361c.png" width="50%">](https://ensico.pt/)
--
-- ---

-- %% [markdown]
-- <span style="color:darkblue">⚠️ **IMPORTANTE**:</span> <b>PREPARA O JUPYTER</b> executando a célula abaixo.<br>Coloca o cursor na célula e verás que irá ficar com a borda azul. Depois, prime o botão <img src="./img/mini-play.png">  ou utiliza as teclas **shift + enter**.

-- %%
:opt no-lint
:m Data.List
:m Data.Char
:l ./src/ensico.hs
(>>) = flip (.)
or = _or
and = _and
not = _not
length = _length
minimum = _minimum
maximum = _maximum
done

-- %% [markdown]
-- ---
-- ### AULA PRÁTICA 6.1 - Pares, Listas de pares e Fecho-éclair

-- %%
compras = [("pão", 1.89), ("sumo", 0.79), ("leite", 1.20), ("ovos", 2.50), ("queijo", 3.40), ("fiambre", 2.30), ("manteiga", 1.50), ("iogurte", 0.61), ("café", 3.00), ("arroz", 1.10), ("massa", 0.90), ("azeite", 4.49), ("farinha", 0.80), ("fermento", 0.40), ("salsichas", 2.20), ("alface", 1.00), ("kiwis", 1.80), ("brócolos", 1.50), ("cenouras", 0.72), ("batatas", 1.17), ("cebolas", 0.90), ("alho", 0.61), ("pimentos", 0.85), ("uvas", 2.00), ("cereais", 2.40), ("frango", 5.00), ("atum", 1.50), ("ervilhas", 0.80), ("caderno", 0.75)]

-- %% [markdown]
-- #### Pergunta 2

-- %%
compras |> reverse

-- %% [markdown]
--     [("caderno",0.75),("ervilhas",0.8),("atum",1.5),("frango",5.0),("cereais",2.4),("uvas",2.0),("pimentos",0.85),("alho",0.61),("cebolas",0.9),("batatas",1.17),("cenouras",0.72),("br\243colos",1.5),("kiwis",1.8),("alface",1.0),("salsichas",2.2),("fermento",0.4),("farinha",0.8),("azeite",4.49),("massa",0.9),("arroz",1.1),("caf\233",3.0),("iogurte",0.61),("manteiga",1.5),("fiambre",2.3),("queijo",3.4),("ovos",2.5),("leite",1.2),("sumo",0.79),("p\227o",1.89)]
--
--
-- #### Pergunta 3

-- %%
compras |> map snd |> sum

-- %% [markdown]
--     48.08

-- %%
dicioPortuguêsElfês = [("tempestade","Huan"), ("lugar","Iilor"), ("neta","A'A'Sum"), ("floresta","Vandor"), ("assombrado","Aes"), ("encontro","Aelou"), ("professor","Aerister"), ("neta","A'E'Sum"), ("noite","Ahnvae"), ("antigo","Akai'ye"), ("primitivo","Akai'ye"), ("dever","Akh"), ("necessidade","Akh"), ("guerreiro","Akhrua"), ("copo","Aloun"), ("chuva","Alushtas"), ("nuvem","Ammur"), ("conselho","Amrulugek"), ("encontro","Amrulugek"), ("nefasto","Anilessa"), ("pronto","Aniq"), ("sol","Ar"), ("luz solar","Arivae"), ("grande espada","Arkerym"), ("tempestade","Arrn"), ("nobre","Ary"), ("filha","A'Sum"), ("alegria","Avae"), ("menino","Bhin"), ("rapaz","Bhin"), ("lixo","Biir"), ("cogumelo","Blalath"), ("cogumelos","Blalatha"), ("metade","Cha"), ("paz","Cinna"), ("grande","Cor"), ("raio de sol","Crithta"), ("batalha","Dala"), ("filho","Vae"), ("estrela","Daoin"), ("estrelas","Daoine"), ("brilhante","Delimbiyr"), ("descer","Descenthallon"), ("destino","Dharasha"), ("maldade","Drag"), ("colina","Dun"), ("neto","E'A'Sum"), ("amigo","Ebrath"), ("neto","E'E'Sum"), ("matar","Eisliesen"), ("forma","Elaorm"), ("fortaleza","Eska"), ("filho","E'Sum"), ("amor","Evae"), ("intensidade","Evael"), ("um","Fae"), ("forma","Faen"), ("magia","Faer"), ("navegador","Faernos"), ("fogo","Fete"), ("transformado","Fhaorn"), ("invocar","Foqal"), ("conjurar","Foqal"), ("pergaminhos","Glaurach"), ("sombra", "Guenhwyvar"), ("ave","Gyrah"), ("centro","Haera"), ("esconderijo","Holme"), ("verdadeiro","Hond"), ("saltitar","Hykyath"), ("sentinela","Ilaerothil"), ("chuva caindo","Ileleste"), ("atirador","Iolaa"), ("saia","Iorwe"), ("criar","Iquar"), ("criador","Iqua"), ("treinado","Irbryn"), ("granada","Iriador"), ("luz","Ivae"), ("falar","Kaweh"), ("fada","Kehrareth"), ("cavalo","Kelytha"), ("vontade","Kerradu"), ("inimigo","Kery"), ("espada","Kerym"), ("guerreiro","Keryn"), ("trio","Khov"), ("gema","Kiir"), ("gemas","Kiira"), ("marinho","Kintiar"), ("marinhos","Kintiara"), ("agora","Kyed"), ("crescente","La"), ("paz","Laev"), ("levantar","Levarithin"), ("lua cheia","Lharast"), ("talvez","Maethe"), ("reaparecer","Maniferril"), ("voto","Manth"), ("defensor","Mathor"), ("defensores","Mathora"), ("floresta","Mista"), ("escuro","Mor"), ("morte","Mor"), ("cidade","Myth"), ("destino","Nanta"), ("procurar","Wutheh"), ("grande","Za"), ("destinos","Nantar"), ("pedra","Nar"), ("eterno","Nar"), ("acordo","Nias"), ("adaga","Nikym"), ("amor","Nor"), ("pai","O"), ("segredo","Olin"), ("estrela","Olkiir"), ("chefe","Omah"), ("orador","Onal"), ("paz","Ondath"), ("madeira","Or"), ("bosque","Ora"), ("aranha","Orbryn"), ("mãe","O'Si"), ("pai","O'Su"), ("tia","Os'Nys"), ("tia","Osi'Nys"), ("tio","Osi'Tan"), ("tia","Osu'Nys"), ("tio","Osu'Tan"), ("oito","Parlu"), ("bardo","Penaal"), ("tesouro","Piir"), ("quatro","Pye"), ("mais","Quex"), ("grande","Raun"), ("oeste","Ren"), ("fora","Ri"), ("sonho","Ru"), ("estrela","Rua"), ("estrelas","Ruar"), ("fora","Rut"), ("apodrecer","Saurot"), ("assassino","Savalir"), ("amigo","Sha"), ("machado","Shaalth"), ("fada","Shee"), ("ceptro","Shessepra"), ("sombras","Shil"), ("feminino","Si"), ("neve","Sige"), ("neves","Sigen"), ("porco","Slaugh"), ("masculino","Su"), ("santo","Suor"), ("selvagem","Sy"), ("meteoro","Syolkiir"), ("feixe","Ta"), ("aprendiz","Tael"), ("irmão","Tan"), ("enviar","Tanar"), ("exilado","Tanar'ri"), ("corpo","Talas"), ("alma","Talas"), ("prenda","Taran"), ("bem","Te"), ("luar","Teuivae"), ("escudo","Theur"), ("noite","Thil"), ("asa","Thimae"), ("asas","Thimaer"), ("promessa","Thor"), ("voto","Thor"), ("primo","Tyss"), ("primos","Tyssir"), ("fogo","Uskeche"), ("chama","Uskeche"), ("fantasma","Uskeche"), ("pai","Va"), ("mal","Vaarn"), ("florestas","Vandora"), ("desaparecer","Vanessaril"), ("tempo","Adoe"), ("bonito","Veluthe"), ("lobo","Vil"), ("lobos","Vili")]

-- %% [markdown]
-- #### Pergunta 4

-- %%
dicioPortuguêsElfês |> length

-- %% [markdown]
--     186
--
--
-- #### Pergunta 5

-- %%
dicioPortuguêsElfês |> sort

-- %% [markdown]
--     [("acordo","Nias"),("adaga","Nikym"),("agora","Kyed"),("alegria","Avae"),("alma","Talas"),("amigo","Ebrath"),("amigo","Sha"),("amor","Evae"),("amor","Nor"),("antigo","Akai'ye"),("apodrecer","Saurot"),("aprendiz","Tael"),("aranha","Orbryn"),("asa","Thimae"),("asas","Thimaer"),("assassino","Savalir"),("assombrado","Aes"),("atirador","Iolaa"),("ave","Gyrah"),("bardo","Penaal"),("batalha","Dala"),("bem","Te"),("bonito","Veluthe"),("bosque","Ora"),("brilhante","Delimbiyr"),("cavalo","Kelytha"),("centro","Haera"),("ceptro","Shessepra"),("chama","Uskeche"),("chefe","Omah"),("chuva","Alushtas"),("chuva caindo","Ileleste"),("cidade","Myth"),("cogumelo","Blalath"),("cogumelos","Blalatha"),("colina","Dun"),("conjurar","Foqal"),("conselho","Amrulugek"),("copo","Aloun"),("corpo","Talas"),("crescente","La"),("criador","Iqua"),("criar","Iquar"),("defensor","Mathor"),("defensores","Mathora"),("desaparecer","Vanessaril"),("descer","Descenthallon"),("destino","Dharasha"),("destino","Nanta"),("destinos","Nantar"),("dever","Akh"),("encontro","Aelou"),("encontro","Amrulugek"),("enviar","Tanar"),("esconderijo","Holme"),("escudo","Theur"),("escuro","Mor"),("espada","Kerym"),("estrela","Daoin"),("estrela","Olkiir"),("estrela","Rua"),("estrelas","Daoine"),("estrelas","Ruar"),("eterno","Nar"),("exilado","Tanar'ri"),("fada","Kehrareth"),("fada","Shee"),("falar","Kaweh"),("fantasma","Uskeche"),("feixe","Ta"),("feminino","Si"),("filha","A'Sum"),("filho","E'Sum"),("filho","Vae"),("floresta","Mista"),("floresta","Vandor"),("florestas","Vandora"),("fogo","Fete"),("fogo","Uskeche"),("fora","Ri"),("fora","Rut"),("forma","Elaorm"),("forma","Faen"),("fortaleza","Eska"),("gema","Kiir"),("gemas","Kiira"),("granada","Iriador"),("grande","Cor"),("grande","Raun"),("grande","Za"),("grande espada","Arkerym"),("guerreiro","Akhrua"),("guerreiro","Keryn"),("inimigo","Kery"),("intensidade","Evael"),("invocar","Foqal"),("irm\227o","Tan"),("levantar","Levarithin"),("lixo","Biir"),("lobo","Vil"),("lobos","Vili"),("lua cheia","Lharast"),("luar","Teuivae"),("lugar","Iilor"),("luz","Ivae"),("luz solar","Arivae"),("machado","Shaalth"),("madeira","Or"),("magia","Faer"),("mais","Quex"),("mal","Vaarn"),("maldade","Drag"),("marinho","Kintiar"),("marinhos","Kintiara"),("masculino","Su"),("matar","Eisliesen"),("menino","Bhin"),("metade","Cha"),("meteoro","Syolkiir"),("morte","Mor"),("m\227e","O'Si"),("navegador","Faernos"),("necessidade","Akh"),("nefasto","Anilessa"),("neta","A'A'Sum"),("neta","A'E'Sum"),("neto","E'A'Sum"),("neto","E'E'Sum"),("neve","Sige"),("neves","Sigen"),("nobre","Ary"),("noite","Ahnvae"),("noite","Thil"),("nuvem","Ammur"),("oeste","Ren"),("oito","Parlu"),("orador","Onal"),("pai","O"),("pai","O'Su"),("pai","Va"),("paz","Cinna"),("paz","Laev"),("paz","Ondath"),("pedra","Nar"),("pergaminhos","Glaurach"),("porco","Slaugh"),("prenda","Taran"),("primitivo","Akai'ye"),("primo","Tyss"),("primos","Tyssir"),("procurar","Wutheh"),("professor","Aerister"),("promessa","Thor"),("pronto","Aniq"),("quatro","Pye"),("raio de sol","Crithta"),("rapaz","Bhin"),("reaparecer","Maniferril"),("saia","Iorwe"),("saltitar","Hykyath"),("santo","Suor"),("segredo","Olin"),("selvagem","Sy"),("sentinela","Ilaerothil"),("sol","Ar"),("sombra","Guenhwyvar"),("sombras","Shil"),("sonho","Ru"),("talvez","Maethe"),("tempestade","Arrn"),("tempestade","Huan"),("tempo","Adoe"),("tesouro","Piir"),("tia","Os'Nys"),("tia","Osi'Nys"),("tia","Osu'Nys"),("tio","Osi'Tan"),("tio","Osu'Tan"),("transformado","Fhaorn"),("treinado","Irbryn"),("trio","Khov"),("um","Fae"),("verdadeiro","Hond"),("vontade","Kerradu"),("voto","Manth"),("voto","Thor")]
--
--
-- Respostas das 4 versões desta pergunta:
--
-- Aranha - Orbryn;
-- Lobo - Vil;
-- Tempo - Adoe.
--
-- Fantasma - Uskeche;
-- Machado - Shaalth;
-- Sol - Ar.
--
-- Bonito - Veluthe;
-- Nuvem - Ammur;
-- Porco - Slaugh.
--
-- Asa - Thimae;
-- Chuva - Alushtas;
-- Talvez - Maethe.
--
-- #### Pergunta 6

-- %%
dicioPortuguêsElfês |> map fst |> nub |> sort

-- %% [markdown]
--     ["acordo","adaga","agora","alegria","alma","amigo","amor","antigo","apodrecer","aprendiz","aranha","asa","asas","assassino","assombrado","atirador","ave","bardo","batalha","bem","bonito","bosque","brilhante","cavalo","centro","ceptro","chama","chefe","chuva","chuva caindo","cidade","cogumelo","cogumelos","colina","conjurar","conselho","copo","corpo","crescente","criador","criar","defensor","defensores","desaparecer","descer","destino","destinos","dever","encontro","enviar","esconderijo","escudo","escuro","espada","estrela","estrelas","eterno","exilado","fada","falar","fantasma","feixe","feminino","filha","filho","floresta","florestas","fogo","fora","forma","fortaleza","gema","gemas","granada","grande","grande espada","guerreiro","inimigo","intensidade","invocar","irm\227o","levantar","lixo","lobo","lobos","lua cheia","luar","lugar","luz","luz solar","machado","madeira","magia","mais","mal","maldade","marinho","marinhos","masculino","matar","menino","metade","meteoro","morte","m\227e","navegador","necessidade","nefasto","neta","neto","neve","neves","nobre","noite","nuvem","oeste","oito","orador","pai","paz","pedra","pergaminhos","porco","prenda","primitivo","primo","primos","procurar","professor","promessa","pronto","quatro","raio de sol","rapaz","reaparecer","saia","saltitar","santo","segredo","selvagem","sentinela","sol","sombra","sombras","sonho","talvez","tempestade","tempo","tesouro","tia","tio","transformado","treinado","trio","um","verdadeiro","vontade","voto"]

("Spearow","normal"),("Spearow","voador"),("Fearow","normal"),("Fearow","voador"),("Ekans","veneno"),("Arbok","veneno"),("Pikachu","eletrico"),("Raichu","eletrico"),("Sandshrew","terra"),("Sandslash","terra"),("Nidoran-f","veneno"),("Nidorina","veneno"),("Nidoqueen","veneno"),("Nidoqueen","terra"),("Nidoran-m","veneno"),("Nidorino","veneno"),("Nidoking","veneno"),("Nidoking","terra"),("Clefairy","fada"),("Clefable","fada"),("Vulpix","fogo"),("Ninetales","fogo"),("Jigglypuff","normal"),("Jigglypuff","fada"),("Wigglytuff","normal"),("Wigglytuff","fada"),("Zubat","veneno"),("Zubat","voador"),("Golbat","veneno"),("Golbat","voador"),("Oddish","erva"),("Oddish","veneno"),("Gloom","erva"),("Gloom","veneno"),("Vileplume","erva"),("Vileplume","veneno"),("Paras","inseto"),("Paras","erva"),("Parasect","inseto"),("Parasect","erva"),("Venonat","inseto"),("Venonat","veneno"),("Venomoth","inseto"),("Venomoth","veneno"),("Diglett","terra"),("Dugtrio","terra"),("Meowth","normal"),("Persian","normal"),("Psyduck","agua"),("Golduck","agua"),("Mankey","lutador"),("Primeape","lutador"),("Growlithe","fogo"),("Arcanine","fogo"),("Poliwag","agua"),("Poliwhirl","agua"),("Poliwrath","agua"),("Poliwrath","lutador"),("Abra","psiquico"),("Kadabra","psiquico"),("Alakazam","psiquico"),("Machop","lutador"),("Machoke","lutador"),("Machamp","lutador"),("Bellsprout","erva"),("Bellsprout","veneno"),("Weepinbell","erva"),("Weepinbell","veneno"),("Victreebel","erva"),("Victreebel","veneno"),("Tentacool","agua"),("Tentacool","veneno"),("Tentacruel","agua"),("Tentacruel","veneno"),("Geodude","rocha"),("Geodude","terra"),("Graveler","rocha"),("Graveler","terra"),("Golem","rocha"),("Golem","terra"),("Ponyta","fogo"),("Rapidash","fogo"),("Slowpoke","agua"),("Slowpoke","psiquico"),("Slowbro","agua"),("Slowbro","psiquico"),("Magnemite","eletrico"),("Magnemite","a\231o"),("Magneton","eletrico"),("Magneton","a\231o"),("Farfetchd","normal"),("Farfetchd","voador"),("Doduo","normal"),("Doduo","voador"),("Dodrio","normal"),("Dodrio","voador"),("Seel","agua"),("Dewgong","agua"),("Dewgong","gelo"),("Grimer","veneno"),("Muk","veneno"),("Shellder","agua"),("Cloyster","agua"),("Cloyster","gelo"),("Gastly","fantasma"),("Gastly","veneno"),("Haunter","fantasma"),("Haunter","veneno"),("Gengar","fantasma"),("Gengar","veneno"),("Onix","rocha"),("Onix","terra"),("Drowzee","psiquico"),("Hypno","psiquico"),("Krabby","agua"),("Kingler","agua"),("Voltorb","eletrico"),("Electrode","eletrico"),("Exeggcute","erva"),("Exeggcute","psiquico"),("Exeggutor","erva"),("Exeggutor","psiquico"),("Cubone","terra"),("Marowak","terra"),("Hitmonlee","lutador"),("Hitmonchan","lutador"),("Lickitung","normal"),("Koffing","veneno"),("Weezing","veneno"),("Rhyhorn","terra"),("Rhyhorn","rocha"),("Rhydon","terra"),("Rhydon","rocha"),("Chansey","normal"),("Tangela","erva"),("Kangaskhan","normal"),("Horsea","agua"),("Seadra","agua"),("Goldeen","agua"),("Seaking","agua"),("Staryu","agua"),("Starmie","agua"),("Starmie","psiquico"),("Mr-mime","psiquico"),("Mr-mime","fada"),("Scyther","inseto"),("Scyther","voador"),("Jynx","gelo"),("Jynx","psiquico"),("Electabuzz","eletrico"),("Magmar","fogo"),("Pinsir","inseto"),("Tauros","normal"),("Magikarp","agua"),("Gyarados","agua"),("Gyarados","voador"),("Lapras","agua"),("Lapras","gelo"),("Ditto","normal"),("Eevee","normal"),("Vaporeon","agua"),("Jolteon","eletrico"),("Flareon","fogo"),("Porygon","normal"),("Omanyte","rocha"),("Omanyte","agua"),("Omastar","rocha"),("Omastar","agua"),("Kabuto","rocha"),("Kabuto","agua"),("Kabutops","rocha"),("Kabutops","agua"),("Aerodactyl","rocha"),("Aerodactyl","voador"),("Snorlax","normal"),("Articuno","gelo"),("Articuno","voador"),("Zapdos","eletrico"),("Zapdos","voador"),("Moltres","fogo"),("Moltres","voador"),("Dratini","dragao"),("Dragonair","dragao"),("Dragonite","dragao"),("Dragonite","voador"),("Mewtwo","psiquico"),("Mew","psiquico")]
--
--
-- #### Pergunta 8

-- %%
poke # tipos |> sort

-- %% [markdown]
--     [("Abra","psiquico"),("Aerodactyl","rocha"),("Aerodactyl","voador"),("Alakazam","psiquico"),("Arbok","veneno"),("Arcanine","fogo"),("Articuno","gelo"),("Articuno","voador"),("Beedrill","inseto"),("Beedrill","veneno"),("Bellsprout","erva"),("Bellsprout","veneno"),("Blastoise","agua"),("Bulbasaur","erva"),("Bulbasaur","veneno"),("Butterfree","inseto"),("Butterfree","voador"),("Caterpie","inseto"),("Chansey","normal"),("Charizard","fogo"),("Charizard","voador"),("Charmander","fogo"),("Charmeleon","fogo"),("Clefable","fada"),("Clefairy","fada"),("Cloyster","agua"),("Cloyster","gelo"),("Cubone","terra"),("Dewgong","agua"),("Dewgong","gelo"),("Diglett","terra"),("Ditto","normal"),("Dodrio","normal"),("Dodrio","voador"),("Doduo","normal"),("Doduo","voador"),("Dragonair","dragao"),("Dragonite","dragao"),("Dragonite","voador"),("Dratini","dragao"),("Drowzee","psiquico"),("Dugtrio","terra"),("Eevee","normal"),("Ekans","veneno"),("Electabuzz","eletrico"),("Electrode","eletrico"),("Exeggcute","erva"),("Exeggcute","psiquico"),("Exeggutor","erva"),("Exeggutor","psiquico"),("Farfetchd","normal"),("Farfetchd","voador"),("Fearow","normal"),("Fearow","voador"),("Flareon","fogo"),("Gastly","fantasma"),("Gastly","veneno"),("Gengar","fantasma"),("Gengar","veneno"),("Geodude","rocha"),("Geodude","terra"),("Gloom","erva"),("Gloom","veneno"),("Golbat","veneno"),("Golbat","voador"),("Goldeen","agua"),("Golduck","agua"),("Golem","rocha"),("Golem","terra"),("Graveler","rocha"),("Graveler","terra"),("Grimer","veneno"),("Growlithe","fogo"),("Gyarados","agua"),("Gyarados","voador"),("Haunter","fantasma"),("Haunter","veneno"),("Hitmonchan","lutador"),("Hitmonlee","lutador"),("Horsea","agua"),("Hypno","psiquico"),("Ivysaur","erva"),("Ivysaur","veneno"),("Jigglypuff","fada"),("Jigglypuff","normal"),("Jolteon","eletrico"),("Jynx","gelo"),("Jynx","psiquico"),("Kabuto","agua"),("Kabuto","rocha"),("Kabutops","agua"),("Kabutops","rocha"),("Kadabra","psiquico"),("Kakuna","inseto"),("Kakuna","veneno"),("Kangaskhan","normal"),("Kingler","agua"),("Koffing","veneno"),("Krabby","agua"),("Lapras","agua"),("Lapras","gelo"),("Lickitung","normal"),("Machamp","lutador"),("Machoke","lutador"),("Machop","lutador"),("Magikarp","agua"),("Magmar","fogo"),("Magnemite","a\231o"),("Magnemite","eletrico"),("Magneton","a\231o"),("Magneton","eletrico"),("Mankey","lutador"),("Marowak","terra"),("Meowth","normal"),("Metapod","inseto"),("Mew","psiquico"),("Mewtwo","psiquico"),("Moltres","fogo"),("Moltres","voador"),("Mr-mime","fada"),("Mr-mime","psiquico"),("Muk","veneno"),("Nidoking","terra"),("Nidoking","veneno"),("Nidoqueen","terra"),("Nidoqueen","veneno"),("Nidoran-f","veneno"),("Nidoran-m","veneno"),("Nidorina","veneno"),("Nidorino","veneno"),("Ninetales","fogo"),("Oddish","erva"),("Oddish","veneno"),("Omanyte","agua"),("Omanyte","rocha"),("Omastar","agua"),("Omastar","rocha"),("Onix","rocha"),("Onix","terra"),("Paras","erva"),("Paras","inseto"),("Parasect","erva"),("Parasect","inseto"),("Persian","normal"),("Pidgeot","normal"),("Pidgeot","voador"),("Pidgeotto","normal"),("Pidgeotto","voador"),("Pidgey","normal"),("Pidgey","voador"),("Pikachu","eletrico"),("Pinsir","inseto"),("Poliwag","agua"),("Poliwhirl","agua"),("Poliwrath","agua"),("Poliwrath","lutador"),("Ponyta","fogo"),("Porygon","normal"),("Primeape","lutador"),("Psyduck","agua"),("Raichu","eletrico"),("Rapidash","fogo"),("Raticate","normal"),("Rattata","normal"),("Rhydon","rocha"),("Rhydon","terra"),("Rhyhorn","rocha"),("Rhyhorn","terra"),("Sandshrew","terra"),("Sandslash","terra"),("Scyther","inseto"),("Scyther","voador"),("Seadra","agua"),("Seaking","agua"),("Seel","agua"),("Shellder","agua"),("Slowbro","agua"),("Slowbro","psiquico"),("Slowpoke","agua"),("Slowpoke","psiquico"),("Snorlax","normal"),("Spearow","normal"),("Spearow","voador"),("Squirtle","agua"),("Starmie","agua"),("Starmie","psiquico"),("Staryu","agua"),("Tangela","erva"),("Tauros","normal"),("Tentacool","agua"),("Tentacool","veneno"),("Tentacruel","agua"),("Tentacruel","veneno"),("Vaporeon","agua"),("Venomoth","inseto"),("Venomoth","veneno"),("Venonat","inseto"),("Venonat","veneno"),("Venusaur","erva"),("Venusaur","veneno"),("Victreebel","erva"),("Victreebel","veneno"),("Vileplume","erva"),("Vileplume","veneno"),("Voltorb","eletrico"),("Vulpix","fogo"),("Wartortle","agua"),("Weedle","inseto"),("Weedle","veneno"),("Weepinbell","erva"),("Weepinbell","veneno"),("Weezing","veneno"),("Wigglytuff","fada"),("Wigglytuff","normal"),("Zapdos","eletrico"),("Zapdos","voador"),("Zubat","veneno"),("Zubat","voador")]
--
-- ---
-- ### AULA PRÁTICA 6.2 - Pares, Listas de pares e Fecho-éclair

-- %%
olimps = [ (1904,"Saint Louis"), (1908,"Londres"), (1964,"Tóquio"), (1948,"Londres"), (2024,"Paris"), (1972,"Munique"), (2008,"Pequim"), (1976,"Montreal"), (2012,"Londres"), (1924,"Chamonix"), (1906,"Atenas"), (1968,"Grenoble"), (1988,"Seul"), (2006,"Turim"), (2016,"Rio de Janeiro"), (1980,"Lake Placid"), (1972,"Sapporo"), (1998,"Nagano"), (1936,"Berlim"), (2000,"Sydney"), (2014,"Sóchi"), (1924,"Paris"), (1932,"Los Angeles"), (1956,"Melbourne"), (1896,"Atenas"), (1936,"Garmisch-Partenkirchen"), (1988,"Calgary"), (1952,"Oslo"), (1960,"Roma"), (1932,"Lake Placid"), (1956,"Cortina d'Ampezzo"), (1968,"Cidade do México"), (1956,"Estocolmo"), (2020,"Tóquio"), (1996,"Atlanta"), (1980,"Moscovo"), (2002,"Salt Lake City"), (1976,"Innsbruck"), (1912,"Estocolmo"), (1928,"Saint Moritz"), (1960,"Squaw Vailley"), (1952,"Helsínquia"), (2018,"PyeongChang"), (1928,"Amsterdão"), (1948,"Saint-Moritz"), (1984,"Sarajevo"), (1994,"Lillehammer"), (1984,"Los Angeles"), (1900,"Paris"), (1920,"Antuérpia"), (2010,"Vancouver"), (1964,"Innsbruck"), (1992,"Albertville"), (1992,"Barcelona"), (2004,"Atenas"), (2022,"Pequim") ]

-- %% [markdown]
-- #### Pergunta 2

-- %%
olimps |> sort

-- %% [markdown]
--     [(1896,"Atenas"),(1900,"Paris"),(1904,"Saint Louis"),(1906,"Atenas"),(1908,"Londres"),(1912,"Estocolmo"),(1920,"Antu\233rpia"),(1924,"Chamonix"),(1924,"Paris"),(1928,"Amsterd\227o"),(1928,"Saint Moritz"),(1932,"Lake Placid"),(1932,"Los Angeles"),(1936,"Berlim"),(1936,"Garmisch-Partenkirchen"),(1948,"Londres"),(1948,"Saint-Moritz"),(1952,"Hels\237nquia"),(1952,"Oslo"),(1956,"Cortina d'Ampezzo"),(1956,"Estocolmo"),(1956,"Melbourne"),(1960,"Roma"),(1960,"Squaw Vailley"),(1964,"Innsbruck"),(1964,"T\243quio"),(1968,"Cidade do M\233xico"),(1968,"Grenoble"),(1972,"Munique"),(1972,"Sapporo"),(1976,"Innsbruck"),(1976,"Montreal"),(1980,"Lake Placid"),(1980,"Moscovo"),(1984,"Los Angeles"),(1984,"Sarajevo"),(1988,"Calgary"),(1988,"Seul"),(1992,"Albertville"),(1992,"Barcelona"),(1994,"Lillehammer"),(1996,"Atlanta"),(1998,"Nagano"),(2000,"Sydney"),(2002,"Salt Lake City"),(2004,"Atenas"),(2006,"Turim"),(2008,"Pequim"),(2010,"Vancouver"),(2012,"Londres"),(2014,"S\243chi"),(2016,"Rio de Janeiro"),(2018,"PyeongChang"),(2020,"T\243quio"),(2022,"Pequim"),(2024,"Paris")]
--
--
-- #### Pergunta 3

-- %%
olimps |> map snd

-- %% [markdown]
--     ["Saint Louis","Londres","T\243quio","Londres","Paris","Munique","Pequim","Montreal","Londres","Chamonix","Atenas","Grenoble","Seul","Turim","Rio de Janeiro","Lake Placid","Sapporo","Nagano","Berlim","Sydney","S\243chi","Paris","Los Angeles","Melbourne","Atenas","Garmisch-Partenkirchen","Calgary","Oslo","Roma","Lake Placid","Cortina d'Ampezzo","Cidade do M\233xico","Estocolmo","T\243quio","Atlanta","Moscovo","Salt Lake City","Innsbruck","Estocolmo","Saint Moritz","Squaw Vailley","Hels\237nquia","PyeongChang","Amsterd\227o","Saint-Moritz","Sarajevo","Lillehammer","Los Angeles","Paris","Antu\233rpia","Vancouver","Innsbruck","Albertville","Barcelona","Atenas","Pequim"]
--
--
-- #### Pergunta 4

-- %%
olimps |> map snd |> nub |> length

-- %% [markdown]
--     44

-- %%
lista2 = [ (("Saint Louis","Estados Unidos"),1904), (("Londres","Grã-Bretanha"),1908), (("Tóquio","Japão"),1964), (("Londres","Grã-Bretanha"),1948), (("Paris","França"),2024), (("Munique","Alemanha"),1972), (("Pequim","China"),2008), (("Montreal","Canadá"),1976), (("Londres","Grã-Bretanha"),2012), (("Chamonix","França"),1924), (("Atenas","Grécia"),1906), (("Grenoble","França"),1968), (("Seul","Coreia do Sul"),1988), (("Turim","Itália"),2006), (("Rio de Janeiro","Brasil"),2016), (("Lake Placid","Estados Unidos"),1980), (("Sapporo","Japão"),1972), (("Nagano","Japão"),1998), (("Berlim","Alemanha"),1936), (("Sydney","Austrália"),2000), (("Sóchi","Rússia"),2014), (("Paris","França"),1924), (("Los Angeles","Estados Unidos"),1932), (("Melbourne","Austrália"),1956), (("Atenas","Grécia"),1896), (("Garmisch-Partenkirchen","Alemanha"),1936), (("Calgary","Canadá"),1988), (("Oslo","Noruega"),1952), (("Roma","Itália"),1960), (("Lake Placid","Estados Unidos"),1932), (("Cortina d'Ampezzo","Itália"),1956), (("Cidade do México","México"),1968), (("Estocolmo","Suécia"),1956), (("Tóquio","Japão"),2020), (("Atlanta","Estados Unidos"),1996), (("Moscovo","União Soviética"),1980), (("Salt Lake City","Estados Unidos"),2002), (("Innsbruck","Áustria"),1976), (("Estocolmo","Suécia"),1912), (("Saint Moritz","Suiça"),1928), (("Squaw Vailley","Estados Unidos"),1960), (("Helsínquia","Finlândia"),1952), (("PyeongChang","Coreia do Sul"),2018), (("Amsterdão","Países Baixos"),1928), (("Saint-Moritz","Suíça"),1948), (("Sarajevo","Jugoslávia"),1984), (("Lillehammer","Noruega"),1994), (("Los Angeles","Estados Unidos"),1984), (("Paris","França"),1900), (("Antuérpia","Bélgica"),1920), (("Vancouver","Canadá"),2010), (("Innsbruck","Áustria"),1964), (("Albertville","França"),1992), (("Barcelona","Espanha"),1992), (("Atenas","Grécia"),2004), (("Pequim","China"),2022) ]

-- %% [markdown]
-- #### Pergunta 5

-- %%
lista2 |> sort

-- %% [markdown]
--     [(("Albertville","Fran\231a"),1992),(("Amsterd\227o","Pa\237ses Baixos"),1928),(("Antu\233rpia","B\233lgica"),1920),(("Atenas","Gr\233cia"),1896),(("Atenas","Gr\233cia"),1906),(("Atenas","Gr\233cia"),2004),(("Atlanta","Estados Unidos"),1996),(("Barcelona","Espanha"),1992),(("Berlim","Alemanha"),1936),(("Calgary","Canad\225"),1988),(("Chamonix","Fran\231a"),1924),(("Cidade do M\233xico","M\233xico"),1968),(("Cortina d'Ampezzo","It\225lia"),1956),(("Estocolmo","Su\233cia"),1912),(("Estocolmo","Su\233cia"),1956),(("Garmisch-Partenkirchen","Alemanha"),1936),(("Grenoble","Fran\231a"),1968),(("Hels\237nquia","Finl\226ndia"),1952),(("Innsbruck","\193ustria"),1964),(("Innsbruck","\193ustria"),1976),(("Lake Placid","Estados Unidos"),1932),(("Lake Placid","Estados Unidos"),1980),(("Lillehammer","Noruega"),1994),(("Londres","Gr\227-Bretanha"),1908),(("Londres","Gr\227-Bretanha"),1948),(("Londres","Gr\227-Bretanha"),2012),(("Los Angeles","Estados Unidos"),1932),(("Los Angeles","Estados Unidos"),1984),(("Melbourne","Austr\225lia"),1956),(("Montreal","Canad\225"),1976),(("Moscovo","Uni\227o Sovi\233tica"),1980),(("Munique","Alemanha"),1972),(("Nagano","Jap\227o"),1998),(("Oslo","Noruega"),1952),(("Paris","Fran\231a"),1900),(("Paris","Fran\231a"),1924),(("Paris","Fran\231a"),2024),(("Pequim","China"),2008),(("Pequim","China"),2022),(("PyeongChang","Coreia do Sul"),2018),(("Rio de Janeiro","Brasil"),2016),(("Roma","It\225lia"),1960),(("Saint Louis","Estados Unidos"),1904),(("Saint Moritz","Sui\231a"),1928),(("Saint-Moritz","Su\237\231a"),1948),(("Salt Lake City","Estados Unidos"),2002),(("Sapporo","Jap\227o"),1972),(("Sarajevo","Jugosl\225via"),1984),(("Seul","Coreia do Sul"),1988),(("Squaw Vailley","Estados Unidos"),1960),(("Sydney","Austr\225lia"),2000),(("S\243chi","R\250ssia"),2014),(("Turim","It\225lia"),2006),(("T\243quio","Jap\227o"),1964),(("T\243quio","Jap\227o"),2020),(("Vancouver","Canad\225"),2010)]
--
--
-- Respostas das 4 versões desta pergunta:
--
-- Calgary - Canadá;
-- PyeongChang - Coreia do Sul;
-- Grenoble - França.
--
-- Vancouver - Canadá;
-- Chamonix - Frnaça;
-- Lillehammer - Noruega.
--
-- Calgary - Canadá;
-- PyeongChang - Coreia do Sul;
-- Chamonix - Frnaça.
--
-- Vancouver - Canadá;
-- Grenoble - França;
-- Lillehammer - Noruega.
--
-- #### Pergunta 6

-- %%
paises = lista2 |> map fst |> map snd
paises

-- %% [markdown]
--     ["Estados Unidos","Gr\227-Bretanha","Jap\227o","Gr\227-Bretanha","Fran\231a","Alemanha","China","Canad\225","Gr\227-Bretanha","Fran\231a","Gr\233cia","Fran\231a","Coreia do Sul","It\225lia","Brasil","Estados Unidos","Jap\227o","Jap\227o","Alemanha","Austr\225lia","R\250ssia","Fran\231a","Estados Unidos","Austr\225lia","Gr\233cia","Alemanha","Canad\225","Noruega","It\225lia","Estados Unidos","It\225lia","M\233xico","Su\233cia","Jap\227o","Estados Unidos","Uni\227o Sovi\233tica","Estados Unidos","\193ustria","Su\233cia","Sui\231a","Estados Unidos","Finl\226ndia","Coreia do Sul","Pa\237ses Baixos","Su\237\231a","Jugosl\225via","Noruega","Estados Unidos","Fran\231a","B\233lgica","Canad\225","\193ustria","Fran\231a","Espanha","Gr\233cia","China"]
--
--
-- Resposta: Estocolmo e Melbourne
--
-- #### Pergunta 3

-- %%
cidades = [ ("Atenas","Grécia"), ("Paris","França"), ("Saint Louis","Estados Unidos da América"), ("Atenas","Grécia"), ("Londres","Inglaterra"), ("Estocolmo","Suécia"), ("Antuérpia","Bélgica"), ("Chamonix","França"), ("Paris","França"), ("Saint Moritz","Suíça"), ("Amesterdão","Países Baixos"), ("Lake Placid","Estados Unidos da América"), ("Los Angeles","Estados Unidos da América"), ("Garmisch-Partenkirchen","Alemanha"), ("Berlim","Alemanha"), ("Saint Moritz","Suíça"), ("Londres","Inglaterra"), ("Oslo","Noruega"), ("Helsínquia","Finlândia"), ("Cortina d'Ampezzo","Itália"), ("Melbourne","Austrália"), ("Estocolmo","Suécia"), ("Squaw Vailley","Estados Unidos da América"), ("Roma","Itália"), ("Innsbruck","Áustria"), ("Tóquio","Japão"), ("Grenoble","França"), ("Cidade do México","México"), ("Sapporo","Japão"), ("Munique","Alemanha"), ("Innsbruck","Áustria"), ("Montreal","Canadá"), ("Lake Placid","Estados Unidos da América"), ("Moscovo","Rússia"), ("Sarajevo","Iugoslávia"), ("Los Angeles","Estados Unidos da América"), ("Calgary","Canadá"), ("Seul","Coreia do Sul"), ("Albertville","França"), ("Barcelona","Espanha"), ("Lillehammer","Noruega"), ("Atlanta","Estados Unidos da América"), ("Nagano","Japão"), ("Sydney","Austrália"), ("Salt Lake City","Estados Unidos da América"), ("Atenas","Grécia"), ("Turim","Itália"), ("Pequim","China"), ("Vancouver","Canadá"), ("Londres","Inglaterra"), ("Sóchi","Rússia"), ("Rio de Janeiro","Brasil"), ("PyeongChang","Coreia do Sul"), ("Tóquio","Japão"), ("Pequim","China"), ("Paris","França") ]

-- %%
cidades |> sort

-- %% [markdown]
--     [("Albertville","Fran\231a"),("Amesterd\227o","Pa\237ses Baixos"),("Antu\233rpia","B\233lgica"),("Atenas","Gr\233cia"),("Atenas","Gr\233cia"),("Atenas","Gr\233cia"),("Atlanta","Estados Unidos da Am\233rica"),("Barcelona","Espanha"),("Berlim","Alemanha"),("Calgary","Canad\225"),("Chamonix","Fran\231a"),("Cidade do M\233xico","M\233xico"),("Cortina d'Ampezzo","It\225lia"),("Estocolmo","Su\233cia"),("Estocolmo","Su\233cia"),("Garmisch-Partenkirchen","Alemanha"),("Grenoble","Fran\231a"),("Hels\237nquia","Finl\226ndia"),("Innsbruck","\193ustria"),("Innsbruck","\193ustria"),("Lake Placid","Estados Unidos da Am\233rica"),("Lake Placid","Estados Unidos da Am\233rica"),("Lillehammer","Noruega"),("Londres","Inglaterra"),("Londres","Inglaterra"),("Londres","Inglaterra"),("Los Angeles","Estados Unidos da Am\233rica"),("Los Angeles","Estados Unidos da Am\233rica"),("Melbourne","Austr\225lia"),("Montreal","Canad\225"),("Moscovo","R\250ssia"),("Munique","Alemanha"),("Nagano","Jap\227o"),("Oslo","Noruega"),("Paris","Fran\231a"),("Paris","Fran\231a"),("Paris","Fran\231a"),("Pequim","China"),("Pequim","China"),("PyeongChang","Coreia do Sul"),("Rio de Janeiro","Brasil"),("Roma","It\225lia"),("Saint Louis","Estados Unidos da Am\233rica"),("Saint Moritz","Su\237\231a"),("Saint Moritz","Su\237\231a"),("Salt Lake City","Estados Unidos da Am\233rica"),("Sapporo","Jap\227o"),("Sarajevo","Iugosl\225via"),("Seul","Coreia do Sul"),("Squaw Vailley","Estados Unidos da Am\233rica"),("Sydney","Austr\225lia"),("S\243chi","R\250ssia"),("Turim","It\225lia"),("T\243quio","Jap\227o"),("T\243quio","Jap\227o"),("Vancouver","Canad\225")]
--
--
-- Respostas das 3 versões desta pergunta:
--
-- Melbourne - Austrália;
-- Antuérpia - Bélgica;
-- Montreal - Canadá.
--
-- Atlanta - Estados Unidos da América;
-- Amesterdão - Países Baixos;
-- Estocolmo - Suécia.
--
-- Calgary - Canadá;
-- PyeongChang - Coreia do Sul;
-- Nagano - Japão.
--
-- #### Pergunta 4

-- %%
[ "Eliud Kipchoge", "Abdi Nageeye", "Bashir Abdi", "Lawrence Cherono", "Ayad Lamdassem", "Suguru Osako", "Alphonce Felix Simbu", "Galen Rupp", "Othmane El Goumri", "Koen Naert", "Mohamed Reda El Aaraby", "Nicolas Navarro", "Maru Teferi", "Goitom Kifle", "Jeison Alexander Suarez", "Tachlowini Gabriyesos", "Morhad Amdouni", "Hamza Sahli", "Shaohui Yang", "Eyob Ghebrehiwet Faniel", "Daniel Mateo", "Yohanes Ghebregergis", "Abdi Hakin Ulad", "Liam Adams", "Richard Ringer", "Tiidrek Nurme", "Girmaw Amare", "Jacob Riley", "Amanal Petros", "Eulalio Munoz", "Jianhua Peng", "Javier Guerra", "Elroy Gelant", "Oqbe Kibrom Ruesom", "Zane Robertson", "Haimro Alame", "Adam Nowicki", "Olivier Irabaruta", "Sondre Nordstad Moen", "Abdi Abdirahman", "Tomas Hilifa Rainhold", "Derlys Ayala", "Fred Musobo", "Sidi-Hassan Chahdi", "Ben Preisner", "Yassine El Fathaoui", "Trevor Hofbauer", "Jungsub Shim", "Hendrik Pfeiffer", "Filex Chemongesi", "Yavuz Agrali", "Joaquin Arbe", "Christopher Thompson", "Byambajav Tseveenravdan", "Jose Luis Santana Marin", "Guojian Dong", "Kevin Seaward", "Dieter Kersten", "Cristhian Pacheco", "Peter Herzog", "Shogo Nakamura", "Arkadiusz Gardzielewski", "Malcolm Hicks", "Juan Pacheco", "Brett Robinson", "Khoarahlane Seutloali", "Roman Fosti", "Paulo Roberto Paula", "Thijs Nijhuis", "Paul Pollock", "Cameron Levins", "Yuma Hattori", "Jesus Arturo Esparza", "Jorge Castelblanco", "Ivan Zarco Alvarez", "Amos Kipruto", "Bart Van Nunen", "Stephen Mokoka", "Lelisa Desisa", "John Hakizimana", "Kh
-- %%
maratona |> length

-- %% [markdown]
--     106

-- %%
[1..106] # maratona

-- %% [markdown]
--     [(1,("Eliud Kipchoge","2:08:38")),(2,("Abdi Nageeye","2:09:58")),(3,("Bashir Abdi","2:10:00")),(4,("Lawrence Cherono","2:10:02")),(5,("Ayad Lamdassem","2:10:16")),(6,("Suguru Osako","2:10:41")),(7,("Alphonce Felix Simbu","2:11:35")),(8,("Galen Rupp","2:11:41")),(9,("Othmane El Goumri","2:11:58")),(10,("Koen Naert","2:12:13")),(11,("Mohamed Reda El Aaraby","2:12:22")),(12,("Nicolas Navarro","2:12:50")),(13,("Maru Teferi","2:13:02")),(14,("Goitom Kifle","2:13:22")),(15,("Jeison Alexander Suarez","2:13:29")),(16,("Tachlowini Gabriyesos","2:14:02")),(17,("Morhad Amdouni","2:14:33")),(18,("Hamza Sahli","2:14:48")),(19,("Shaohui Yang","2:14:58")),(20,("Eyob Ghebrehiwet Faniel","2:15:11")),(21,("Daniel Mateo","2:15:21")),(22,("Yohanes Ghebregergis","2:15:34")),(23,("Abdi Hakin Ulad","2:15:50")),(24,("Liam Adams","2:15:51")),(25,("Richard Ringer","2:16:08")),(26,("Tiidrek Nurme","2:16:16")),(27,("Girmaw Amare","2:16:17")),(28,("Jacob Riley","2:16:26")),(29,("Amanal Petros","2:16:33")),(30,("Eulalio Munoz","2:16:35")),(31,("Jianhua Peng","2:16:39")),(32,("Javier Guerra","2:16:42")),(33,("Elroy Gelant","2:16:43")),(34,("Oqbe Kibrom Ruesom","2:16:57")),(35,("Zane Robertson","2:17:04")),(36,("Haimro Alame","2:17:17")),(37,("Adam Nowicki","2:17:19")),(38,("Olivier Irabaruta","2:17:44")),(39,("Sondre Nordstad Moen","2:17:59")),(40,("Abdi Abdirahman","2:18:27")),(41,("Tomas Hilifa Rainhold","2:18:28")),(42,("Derlys Ayala","2:18:34")),(43,("Fred Musobo","2:18:39")),(44,("Sidi-Hassan Chahdi","2:18:40")),(45,("Ben Preisner","2:19:27")),(46,("Yassine El Fathaoui","2:19:44")),(47,("Trevor Hofbauer","2:19:57")),(48,("Jungsub Shim","2:20:36")),(49,("Hendrik Pfeiffer","2:20:43")),(50,("Filex Chemongesi","2:20:53")),(51,("Yavuz Agrali","2:21:00")),(52,("Joaquin Arbe","2:21:15")),(53,("Christopher Thompson","2:21:29")),(54,("Byambajav Tseveenravdan","2:21:32")),(55,("Jose Luis Santana Marin","2:21:32")),(56,("Guojian Dong","2:21:35")),(57,("Kevin Seaward","2:21:45")),(58,("Dieter Kersten","2:22:06")),(59,("Cristhian Pacheco","2:22:12")),(60,("Peter Herzog","2:22:15")),(61,("Shogo Nakamura","2:22:23")),(62,("Arkadiusz Gardzielewski","2:22:50")),(63,("Malcolm Hicks","2:23:12")),(64,("Juan Pacheco","2:23:41")),(65,("Brett Robinson","2:24:04")),(66,("Khoarahlane Seutloali","2:25:03")),(67,("Roman Fosti","2:25:37")),(68,("Paulo Roberto Paula","2:26:08")),(69,("Thijs Nijhuis","2:26:59")),(70,("Paul Pollock","2:27:48")),(71,("Cameron Levins","2:28:43")),(72,("Yuma Hattori","2:30:08")),(73,("Jesus Arturo Esparza","2:31:51")),(74,("Jorge Castelblanco","2:33:22")),(75,("Ivan Zarco Alvarez","2:44:36")),(76,("Amos Kipruto","Nao terminou.")),(77,("Bart Van Nunen","Nao terminou.")),(78,("Stephen Mokoka","Nao terminou.")),(79,("Lelisa Desisa","Nao terminou.")),(80,("John Hakizimana","Nao terminou.")),(81,("Khalid Choukoud","Nao terminou.")),(82,("Marcin Chabowski","Nao terminou.")),(83,("Ben Connor","Nao terminou.")),(84,("Pheeha Mokgobo","Nao terminou.")),(85,("Ser-Od Bat-Ochir","Nao terminou.")),(86,("Daniel Ferreira Do Nascimento","Nao terminou.")),(87,("Tadesse Abraham","Nao terminou.")),(88,("Yassine Rachik","Nao terminou.")),(89,("Callum Hawkins","Nao terminou.")),(90,("Bohdan-Ivan Horodyskyy","Nao terminou.")),(91,("Polat Kemboi Arikan","Nao terminou.")),(92,("Ivan Dario Gonzalez","Nao terminou.")),(93,("Sisay Lemma","Nao terminou.")),(94,("Shumi Dechasa","Nao terminou.")),(95,("Mykola Nyzhnyk","Nao terminou.")),(96,("Lemawork Ketema","Nao terminou.")),(97,("Stephen Scullion","Nao terminou.")),(98,("Joohan Oh","Nao terminou.")),(99,("Alemu Bekele","Nao terminou.")),(100,("Stephen Kiprotich","Nao terminou.")),(101,("Gabriel Gerald Geay","Nao terminou.")),(102,("Daniel Da Silva","Nao terminou.")),(103,("Oleksandr Sitkovskiy","Nao terminou.")),(104,("Shura Kitata","Nao terminou.")),(105,("Jack Rayner","Nao terminou.")),(106,("El Hassan Elabbassi","Desqualificado."))]
--
--
-- Respostas das 4 versões desta pergunta:
--
-- 4º lugar: 2:10:02
--
-- 47º lugar: 2:19:57
--
-- 56º lugar: 2:21:35
--
-- 72º lugar: 2:30:08
--
-- #### Pergunta 7

-- %%
maratona |> filter(\elem -> elem |> snd |> (=="Nao terminou.")) |> map fst

-- %% [markdown]
--     ["Amos Kipruto","Bart Van Nunen","Stephen Mokoka","Lelisa Desisa","John Hakizimana","Khalid Choukoud","Marcin Chabowski","Ben Connor","Pheeha Mokgobo","Ser-Od Bat-Ochir","Daniel Ferreira Do Nascimento","Tadesse Abraham","Yassine Rachik","Callum Hawkins","Bohdan-Ivan Horodyskyy","Polat Kemboi Arikan","Ivan Dario Gonzalez","Sisay Lemma","Shumi Dechasa","Mykola Nyzhnyk","Lemawork Ketema","Stephen Scullion","Joohan Oh","Alemu Bekele","Stephen Kiprotich","Gabriel Gerald Geay","Daniel Da Silva","Oleksandr Sitkovskiy","Shura Kitata","Jack Rayner"]
--
--
-- #### Pergunta 8

-- %%
maratona |> filter(\elem -> elem |> snd |> (=="2:16:35"))

-- %% [markdown]
--     [("Eulalio Munoz","2:16:35")]

-- %% [markdown]
-- ---
-- Generated by Ipynb.hs
-- &copy; ENSICO.
-- Time stamp: 2026-03-25 12:48 UTC
